# %%
import pandas as pd

# %%
names = ['Fairy', 'Asim', 'Misha']

# %%
percentages = [40,93,67]

# %%
import matplotlib.pyplot as plt

# %%
plt.title('Ahmeds Lovers')
plt.bar(names, percentages, color = 'red')
# Out:
# <BarContainer object of 3 artists>
